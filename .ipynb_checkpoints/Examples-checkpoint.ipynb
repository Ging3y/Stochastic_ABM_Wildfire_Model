# %%
from src.Agents import Agent, Vegetation, Tree, Water, Shrubs
from src.Environment import Environment

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading a simple environment
#
# An environment needs two things, an environment file which is just a two-dimensional numpy array, and a configuration file which holds all the parameter values for the simulation. We define both paths of these below and then can load an environment.

# %%
env_path = "local/environments/grass_env.npy"
config_path = "config/config.ini"
E = Environment(env_path, config_path)

# %% [markdown]
# # Simple simulation
#
# With an environment, you can now run simulations. We will show a simple worfklow here.

# %% [markdown]
# ### Display environment
#
# Note there is a difference between `E.display()` and `E.display_state()`. The former is the __initial__ state of the environment as provided in the `env_path` file, whereas the latter is the __current__ state, in the case you have started a fire in the environment.

# %%
# Display initial environment
E.display()

# %% [markdown]
# ### See topological and fuel properties of environment
#
# The environment has both topology factors, and fuel properties. You can display them both as so. Recall again each agents fuel is assumed to follow a distribution given in the configuration parameters. Hence if we were to reset our environment, its initial fuel would look slightly different.

# %%
# Show topology
E.display_topology()
E.display_fuel()

# %% [markdown]
# ### Set wind and start initial fire locations
#
# We can set both a static wind direction, and start a fire on any cells, even such as water or dirt, however it would simply burn out if that occured. You can see this below.

# %%
# Set strong wind to upper left corner
E.set_wind(-10,10)

# Set fire to specific cells
for i in range(45,56):
    for j in range(20,23):
        E.start_fire(i,j)

# %%
# Now look at how our environment hasn't changed, but its state has
E.display()
E.display_state()

# %% [markdown]
# ### Simulate forward
#
# We have two methods for simulation, simple and stochastic. The simple method means that if a cell is to catch fire, it catches its neighbors on fire the next time step. The stochastic method is more complicated and takes into account fuel levels, topology, wind, and is obviously random. We will first show the simple method. Notice there are three arguments: `N=25` means we simulate for 25 time steps, `disp=False` means we do not want to plot every time step, `verbose=True` means that it will return two vectors of the amount of available fuel and burned fuel at every time step.

# %%
# Start simple method
available_fuel, burned_fuel = E.simple_step(N=25, disp=False, verbose=True)

# %%
# Display state after simple fire
E.display_state()

# Display fuel burn rates
plt.plot(available_fuel, label="Available")
plt.plot(burned_fuel, label="Burned")
plt.legend()
plt.show()

# %% [markdown]
# We see that with the simplistic fire spreading scheme, it creates a very unrealistic shape, and it also totally ignored our wind parameters! That being said, the rate of which fuel is burned seems to be starting to exponetially increase which mimics real-world behavior. Lets use our more complicated method now.

# %% [markdown]
# ### Running the advanced simulation
#
# Before we run our advanced simulation, we have to __reset__ our environment, as there are many cells that have now caught fire. To do this, we simply have the `E.reset_env()` method. Recall again that when we reset our environment, we will be reassigning fuel weights for each agent according to its own distribution.

# %%
# Show current burned environment
E.display_state()

# Reset environment
E.reset_env()

# Show current state of environment, all fresh and clean
E.display_state()

# %% [markdown]
# ### Run the advanced simulation
#
# Now we simply start a fire in the same locations as last time, and now we can run our more advanced simulation forward. The arguments for the `E.step()` function are the same as the simple simulation, with just different fire transfer logic. Hence `N` gives the time steps forward to simulate, `disp` is a boolean on if we wish to plot every step, and `verbose` will again return the vectors of available and burnt fuel through the simulation.

# %%
# Set fire to specific cells
for i in range(45,56):
    for j in range(20,23):
        E.start_fire(i,j)
        
available_fuel2, burned_fuel2 = E.step(N=25, disp=False, verbose=True)

# %% [markdown]
# ### Look at results
#
# Now we can see that with the fire starting on mainly grass and with such an aggresive wind, the fire shape looks much different. You also may think that with the wind pushing to the upper left corner, why the fire didn't spread there. The reason is likely because looking at the topology map, there is an aggresive slop going downhill from bottom left to upper right. Hence the fire was not able to travel downhill, despite the wind pushing it that way.
#
# We can also compare the rates of fuel between the two simulations, as seen in the comparison line plot.

# %%
# Display fire area
E.display_state()

# Compare burned areas
# Display fuel burn rates
plt.plot(available_fuel, label="Available - Simple")
plt.plot(burned_fuel, label="Burned - Simple")
plt.plot(available_fuel2, label="Available - Stochastic")
plt.plot(burned_fuel2, label="Burned - Stochastic")
plt.legend()
plt.show()

# %% [markdown]
# ### More advanced uses
#
# Lets see you want to not only run a simulation, but get a mask of the current burned area? This is simple with the `get_mask()` method. This will simply return a binary mask of the burned area at the current time step it is called.

# %%
# Get mask
M = E.get_mask()

# Display
plt.imshow(M)
plt.show()

# %% [markdown]
# ### Creating animations
#
# One of the most fun things about creating wildfire simulations are seeing the videos. Not only can you get plots of every step in the simulation by using `E.step(disp=True)`, but you can also leverage the `create_animation()` method to build gifs of the entire simulation as well. Lets create and save a gif of our complex simulation again.
#
# This method takes the parameters of `fname` which is the name of the resulting gif, `N` which is the time steps to move forward, and `complex_` as a boolean which is the ability to use either the stochastic (True) or deterministic simple (False) simulation.

# %%
# Reset environment
E.reset_env()

# Set fire to specific cells
for i in range(45,56):
    for j in range(20,23):
        E.start_fire(i,j)
        
# Simulate forward
E.create_animation(fname='output.gif', N=50, complex_=True)

# %% [markdown]
# If you check in the code directory of `local/gifs/` there will be a gif titled `output.gif` in the desired location! Note that as gifs can be quite large, all gifs are not tracked in github.

# %% [markdown]
# ### Changing configuration files
#
# The configuration files hold all relative parameters for both the aesthetic coloring of images and plots, as well as parameters for the stochastic simulation model. While the meanings of these are described in my project writeup, we can load two environments with different configurations, and compare them against each other. We will do that here, and change both one aesthetic parameter, and one model parameter.
#
# We will use our normal `config.ini` for our base case, with `config_silly.ini` as our test case. In our silly new configuration we changed two things: the color of water is now yellow, and the standard deviation of tree fuels is now tripled from 30 to 60.

# %%
# Define environment path
# Define both configs
env_path = "local/environments/tree_env.npy"
config_path1 = "config/config.ini"
config_path2 = "config/config_silly.ini"

# Load our two seperate environments
E1 = Environment(env_path, config_path1)
E2 = Environment(env_path, config_path2)

E1.display()
E2.display()

# %% [markdown]
# Now we have both enviroments loaded and displayed, we see that our first change is apparent right away, our beautiful lake is now, quite gross looking. However this isn't as important as the model parameter changes. Lets look at how fuel differences look like now with such a higher variance in our second environment.

# %%
E1.display_fuel()
E2.display_fuel()

# %% [markdown]
# We see that the standard deviation being so much higher for trees has now clearly impacted the fuel distribution and we see only 'spots' of red, or high fuel or mature trees, in the second environment. We should now look to see what impact this may have on our environment. Lets run the same simulation across both environments.

# %%
# Start the same fire in both environments
for i in range(80,84):
    for j in range(15,20):
        E1.start_fire(i,j)
        E2.start_fire(i,j)

# Run simulation and get burn vectors
af1, bf1 = E1.step(N=75, disp=False, verbose=True)
af2, bf2 = E2.step(N=75, disp=False, verbose=True)

# Compare burned areas
# Display fuel burn rates
plt.plot(af1, label="Available - Normal")
plt.plot(bf1, label="Burned - Normal")
plt.plot(af2, label="Available - Silly")
plt.plot(bf2, label="Burned - Silly")
plt.legend()
plt.show()

# %% [markdown]
# Wow! It looks like with such a high standard deviation of trees, the small fire wasn't able to catch many on fire before it burned out. Maybe this is a pattern with such a higher standard deviation? Or maybe this was a single random event? Lets run more experiments and find out.

# %% [markdown]
# ### Monte Carlo Experiments
#
# Now we can tie everything together and run some monte carlo experiments. As our simulation __is__ stochastic, we can look at running many different trials and seeing how the respective burn maps turn out for each configuration file.

# %%
# Burn masks
M1, M2 = [], []

for i in range(10):
    # Reset environments
    E1.reset_env()
    E2.reset_env()

    # Start the same fire in both environments
    for i in range(80,84):
        for j in range(15,20):
            E1.start_fire(i,j)
            E2.start_fire(i,j)

    # Run simulation and get burn vectors
    E1.step(N=50, disp=False, verbose=False)
    E2.step(N=50, disp=False, verbose=False)
    
    # Now get our burn mask and append it
    M1.append(E1.get_mask())
    M2.append(E2.get_mask())

# %%
# Get average probability of burning in E1
M1_avg = np.mean(np.array(M1),axis=0)

# Get average probability of burning in E1
M2_avg = np.mean(np.array(M2),axis=0)

# Get av
plt.subplot(121)
plt.title("Environment 1")
plt.imshow(M1_avg, cmap='coolwarm')
plt.subplot(122)
plt.title("Environment 2")
plt.imshow(M2_avg, cmap='coolwarm')
plt.show()

# %% [markdown]
# So from our monte-carlo experiments, it looks like the higher standard deviation of fuel does play a large role in how much our fire spreads. Could this be because of the majority of the environment are trees? Is it because trees have most the fuel and are harder to catch fire? What does this say about how uncertainty in fuel distributions could effect the spread of fire? These are all good questions that I'm not sure how to answer, but this experiment shows how you could go about answering them.

# %% [markdown]
# ### Creating an environment
#
# An environment is simply a numpy array of size `n x m x 2`. Where the first slice, or `[:,:,0]` contains the id's of every agent in the environment. Currently we have vegetation as 0, tree as 1, water as 2, dirt as 3. The second slice, or `[:,:,1]` is the topology or elevation of an environment. By creating an environment that follows this form, you can create any environment you like. Lets build a random one now!

# %%
# Set environment size
n,m=50,50

# Choose agents at random
agents = np.random.randint(0,5,n*m)
A = agents.reshape(n,m)

# Make random elevation gradient
ele = np.ones((n,m))
for i in range(n):
    for j in range(m):
        ele[i,j] = 1.5*i+3*j
        
# Put the two layers together, make sure is (n,m,2)
E = np.stack((A, ele))
E = np.moveaxis(E, 0, -1)

# %% [markdown]
# Now that we have our numpy array, we can save it locally and then load it up and test it as an environment.

# %%
# Save environment at root
np.save("test_env.npy", E)

# Now load
E = Environment("test_env.npy", config_path1) # Just load with old config path

# Look at our random environment
E.display()

# %% [markdown]
# Now we have our random environment! We now can run a simple simulation, but with the rough estimate that 50% of our environment has dirt or water, things likely won't spread far.

# %%
# Start fire at random spots
for i in range(10,25):
    for j in range(13,30):
        E.start_fire(i,j)

# Display
E.display_state()

# Run simulation, showing plots
E.step(N=10, disp=True, verbose=False)

# %% [markdown]
# Here we created a new environment, displayed it, and ran our simulation 10 steps forward. In my case it burned out fairly quickly by step 6-8, but again as this simulation is random at every iteration, behavior will likely be different for you.

# %% [markdown]
# ### Adding another agent to the simulation
#
# When you want to add another agent to the simulation, do the following:
#
# 1. In the `Agents.py` add a new child class by copying a previous child. Change its id (I'd recommend up by 1) and decide if its flammable or not by the binary 1 or 0 respectively. __Also__ change the `flammable` function in the `Agents.py` file to also return the id of the newly added agent __if__ if it is flammable.
#
# 2. Add the proper configuration parameters for the agent in the `config.ini` file. Recall that color is the RGB values for the displayed enviornment, with theta as the value for sigmoid(theta) as the probability it catches fire when introduced to flame.
#
# 3. Modify the `Environments.py` file in the following ways:
#       <br> a. Import the new class from the Agents file
#       <br> b. Set class attributes to read in the appropriate config properties for the agent (under "read in agent config" comment)
#       <br> c. When loading the array A holding agents, add an if statement to build the appropriate agent, given its id value (Comment of "Starts environment over with new fuel distribution and no burn region.")
#
# Once performing all of these steps, you have added a new agent to the available bank you can use to create environments and run simulations!

# %% [markdown]
# # Open Questions
#
# These are some interesting questions, roughly listed in what I would consider the order of difficulty, that I think would be interesting to look into further.
#
# 1. What kind of curves best fit the rate of fuel burning on a fire? Does the parameterization roughly stay the same regardless of initial fire locations or environments?
# 2. What other metrics than total area burned or a burn mask could you use to describe the progress or state of a fire?
# 3. Given an environments makeup of agents, elevation, etc. can you build a regression model to predict total burn area over time given a specific burn area?
# 4. How does behavior of fire change when configurations are altered slightly? Different wind, different elevation, different fuel loads, etc.
# 5. Is our model even realistic? Can we overfit our configuration parameters to provide realistic burn areas of known fires?
# 5. How could we change our stochastic logic to be more realistic? (This is the `src/_stv1.py` file)
#
# These are just some of many questions you could ask with this model. Good luck!
